# %%
import background
import my_visualize as visualize

# %%
winner = background.launch(generations = 200, reporter=False, checkpoint=False)
# Out:
# Best genome:
# Key: 3637
# Fitness: 545.0
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.4562781816184362, response=1.0, activation=sigmoid, aggregation=sum)
# 	7821 DefaultNodeGene(key=7821, bias=-0.8754338601237501, response=1.0, activation=sigmoid, aggregation=sum)
# 	7822 DefaultNodeGene(key=7822, bias=0.5424070378527837, response=1.0, activation=sigmoid, aggregation=sum)
# 	7823 DefaultNodeGene(key=7823, bias=-0.8361612792737335, response=1.0, activation=sigmoid, aggregation=sum)
# 	8061 DefaultNodeGene(key=8061, bias=-1.5242898334117454, response=1.0, activation=sigmoid, aggregation=sum)
# 	8533 DefaultNodeGene(key=8533, bias=-0.22110915711172097, response=1.0, activation=sigmoid, aggregation=sum)
# 	8553 DefaultNodeGene(key=8553, bias=-0.5699969660318683, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-8, 7821), weight=2.5657812946049865, enabled=False)
# 	DefaultConnectionGene(key=(-8, 7822), weight=-4.724836095860879, enabled=True)
# 	DefaultConnectionGene(key=(-8, 7823), weight=0.6794088813666457, enabled=True)
# 	DefaultConnectionGene(key=(-8, 8061), weight=0.07362330614268572, enabled=True)
# 	DefaultConnectionGene(key=(-7, 7821), weight=0.6872203683788345, enabled=True)
# 	DefaultConnectionGene(key=(-7, 7822), weight=3.046818562295665, enabled=False)
# 	DefaultConnectionGene(key=(-7, 7823), weight=-3.1577224639674055, enabled=True)
# 	DefaultConnectionGene(key=(-7, 8533), weight=-0.6320189253783284, enabled=False)
# 	DefaultConnectionGene(key=(-7, 8553), weight=0.17483084972187884, enabled=True)
# 	DefaultConnectionGene(key=(-6, 7821), weight=-0.30804376394086896, enabled=True)
# 	DefaultConnectionGene(key=(-6, 8061), weight=-2.79102457498221, enabled=True)
# 	DefaultConnectionGene(key=(-5, 7821), weight=0.04722259338145163, enabled=True)
# 	DefaultConnectionGene(key=(-5, 7823), weight=-0.1362289307151789, enabled=True)
# 	DefaultConnectionGene(key=(-4, 7822), weight=-0.5422299401659841, enabled=True)
# 	DefaultConnectionGene(key=(-3, 7821), weight=3.4249690656675575, enabled=True)
# 	DefaultConnectionGene(key=(-3, 7823), weight=-0.7155169299281747, enabled=True)
# 	DefaultConnectionGene(key=(-2, 7821), weight=-1.6767821208539895, enabled=True)
# 	DefaultConnectionGene(key=(-2, 7822), weight=1.8566890237993114, enabled=False)
# 	DefaultConnectionGene(key=(-2, 7823), weight=-0.16270054351318175, enabled=True)
# 	DefaultConnectionGene(key=(-1, 7821), weight=-1.8966467587371685, enabled=True)
# 	DefaultConnectionGene(key=(-1, 7822), weight=-1.00345481838464, enabled=True)
# 	DefaultConnectionGene(key=(-1, 7823), weight=1.0126347378843747, enabled=True)
# 	DefaultConnectionGene(key=(7821, 0), weight=-1.2149667007158695, enabled=True)
# 	DefaultConnectionGene(key=(7823, 0), weight=-2.6471181195131486, enabled=True)
# 	DefaultConnectionGene(key=(8061, 7821), weight=1.8934018833238673, enabled=True)
# 	DefaultConnectionGene(key=(8061, 7823), weight=0.19181303883097436, enabled=True)
# 	DefaultConnectionGene(key=(8533, 7822), weight=0.18742126623924435, enabled=True)
# 	DefaultConnectionGene(key=(8553, 8533), weight=0.7809973549455949, enabled=True)
# TP:  128
# TN:  417
# FP:  83
# FN:  140
# accuracy:  0.7096354166666666
# precision:  0.6066350710900474
# IoU:  0.3646723646723647

# %%
background.plot_the_graph(winner)
# Out:
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py:569: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py:660: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
node_names = {-1: 'Pregnancies',
              -2: 'Glucose',
              -3: 'BloodPressure',
              -4: 'SkinThickness',
              -5: 'Insulin',
              -6: 'BMI',
              -7: 'DiabetesPedigreeFunction',
              -8: 'Age',
              0: 'Outcome'}

# %%
background.save_model(winner, 'models/model')

# %%
loaded_winner = background.load_model('D:/')

# %% [markdown]
# -------------------

# %% [markdown]
# # Debug

# %%
list_of_nodes = []
for node in winner.connections.values():
    temp = []
    for neuron in node.key:
        temp.append(neuron)
    temp.append(node.weight)
    list_of_nodes.append(temp)

print(list_of_nodes)
# Out:
# [[-1, 409, 3.2032715935817917], [-2, 409, 1.7082137774761148], [-2, 411, -0.07239245375186765], [-3, 409, -3.8028736412984783], [-3, 411, -0.6467386255395522], [-6, 409, -1.8899913753724062], [-6, 411, -1.719457269357336], [-7, 409, 1.8776244421761592], [-8, 409, 0.5676355231595458], [-8, 411, -0.2919252908811637], [409, 0, 2.5428940902295287], [411, 0, -1.9507285073895821], [-1, 452, -0.9157936816655541], [-6, 571, 2.635094005799273], [571, 409, -0.8050512172312914], [571, 452, 2.8621202355113833], [411, 571, 1.4797336806334336], [-7, 1158, -0.9768797652907525], [1158, 409, 2.4622701614269165], [571, 2128, 0.31591373345890644], [2128, 409, -0.05882021696629314], [1158, 411, 0.9982006377137966]]

# %%
for node in list_of_nodes:
    if node[0] > 0 and node[1] > 0:
        # pop the node
        print(node)
        list_of_nodes.remove(node)
# Out:
# [571, 409, -0.8050512172312914]
# [411, 571, 1.4797336806334336]
# [1158, 409, 2.4622701614269165]
# [2128, 409, -0.05882021696629314]

# %%
print(list_of_nodes)
# Out:
# [[-1, 409, 3.2032715935817917], [-2, 409, 1.7082137774761148], [-2, 411, -0.07239245375186765], [-3, 409, -3.8028736412984783], [-3, 411, -0.6467386255395522], [-6, 409, -1.8899913753724062], [-6, 411, -1.719457269357336], [-7, 409, 1.8776244421761592], [-8, 409, 0.5676355231595458], [-8, 411, -0.2919252908811637], [409, 0, 2.5428940902295287], [411, 0, -1.9507285073895821], [-1, 452, -0.9157936816655541], [-6, 571, 2.635094005799273], [571, 452, 2.8621202355113833], [-7, 1158, -0.9768797652907525], [571, 2128, 0.31591373345890644], [1158, 411, 0.9982006377137966]]

# %%
#plot a graph where the first element of inner list is the first node, the second element is the second node and the third element is the weight of the connection
# the plot must show three levels of neural network. 
# If the node is 0 - it is output. If the node is 85-88 - it is hidden. If the node is -8 - -1- it is input
# the plot must show the connections between the nodes
# the plot must show the weights of the connections

#plot a graph where the first element of inner list is the first node, the second element is the second node and the third element is the weight of the connection

import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
# upper level nodes (input) - 8 nodes
#i = 0
#for node in list_of_nodes:
#    G.add_node(node[0], pos=(0, i))
#    if(node[1] > 0):
#        G.add_node(node[1], pos=(1, (1+i)*2))
#    elif(node[1] == 0):
#        G.add_node(node[1], pos=(2, (1+i)*2))
#    G.add_edge(node[0], node[1], weight=node[2])
#    i += 1

G.add_node(-1, pos=(0, 0))
G.add_node(-2, pos=(0, 1))
G.add_node(-3, pos=(0, 2))
G.add_node(-4, pos=(0, 3))
G.add_node(-5, pos=(0, 4))
G.add_node(-6, pos=(0, 5))
G.add_node(-7, pos=(0, 6))
G.add_node(-8, pos=(0, 7))
# middle level nodes (hidden) - 4 nodes
G.add_node(85, pos=(1, 1))
G.add_node(86, pos=(1, 3))
G.add_node(87, pos=(1, 5))
G.add_node(88, pos=(1, 7))
# lower level nodes (output) - 1 node
G.add_node(0, pos=(2, 4))

# %%
# edges between nodes
for node in list_of_nodes:
    G.add_edge(node[0], node[1], weight=node[2])

## weights of the edges
#G.edges[-1, 85]['weight'] = list_of_nodes[0][2]
#G.edges[-1, 86]['weight'] = list_of_nodes[1][2]

# positions of the nodes
pos = nx.get_node_attributes(G, 'pos')

# color the arrows
edge_colors = ['r' if G[u][v]['weight'] < 0 else 'g' for u,v in G.edges()]
# green for input nodes, yellow for hidden nodes, red for output nodes
node_colors = ['gray' if node < 0 else 'y' if node > 0 else 'pink' for node in G.nodes()]

# weights of the edges
weights = nx.get_edge_attributes(G, 'weight')
# draw the graph
nx.draw(G, pos, with_labels=True, node_color=node_colors, edge_color=edge_colors, node_size=500, arrows=True)
# draw the weights
#nx.draw_networkx_edge_labels(G, pos, edge_labels=weights)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     393     try:
# --> 394         xy = np.asarray([pos[v] for v in nodelist])
#     395     except KeyError as e:
#
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py in <listcomp>(.0)
#     393     try:
# --> 394         xy = np.asarray([pos[v] for v in nodelist])
#     395     except KeyError as e:
#
# KeyError: 409
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9808\3753580943.py in <module>
#      18 weights = nx.get_edge_attributes(G, 'weight')
#      19 # draw the graph
# ---> 20 nx.draw(G, pos, with_labels=True, node_color=node_colors, edge_color=edge_colors, node_size=500, arrows=True)
#      21 # draw the weights
#      22 #nx.draw_networkx_edge_labels(G, pos, edge_labels=weights)
#
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, **kwds)
#     124
#     125     try:
# --> 126         draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127         ax.set_axis_off()
#     128         plt.draw_if_interactive()
#
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     275         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     276
# --> 277     node_collection = draw_networkx_nodes(G, pos, **kwds)
#     278     edge_collection = draw_networkx_edges(G, pos, arrows=arrows, **kwds)
#     279     if with_labels:
#
# c:\anaconda3\envs\neat_\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     394         xy = np.asarray([pos[v] for v in nodelist])
#     395     except KeyError as e:
# --> 396         raise nx.NetworkXError('Node %s has no position.' % e)
#     397     except ValueError:
#     398         raise nx.NetworkXError('Bad value in node positions.')
#
# NetworkXError: Node 409 has no position.

# %%
print(type(winner.connections))
for a, b in winner.connections:
    print(a, b)
# Out:
# <class 'dict'>
# -1 85
# -1 86
# -1 87
# -2 85
# -2 86
# -2 87
# -2 88
# -3 85
# -3 86
# -3 87
# -4 85
# -4 87
# -5 85
# -5 86
# -5 87
# -5 88
# -6 85
# -6 86
# -6 87
# -6 88
# -7 85
# -7 86
# -7 87
# -8 85
# -8 88
# 85 0
# 86 0
# 87 0
# 88 0
# 87 85
# 88 87

# %%
visualize.plot_stats(stats, ylog=False, view=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9808\3917601764.py in <module>
# ----> 1 from background import stats
#       2 visualize.plot_stats(stats, ylog=False, view=True)
#
# ImportError: cannot import name 'stats' from 'background' (c:\Users\7000f\notebooks\лабы\Нейрочел\ProgramCode\background.py)

# %%
config = background.config

# %%
visualize.draw_net(config, winner, True, node_names=node_names)
